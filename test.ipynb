# %% [markdown]
# #### Resultas de backtest manual
#
# 1. 3 Julio BULLISH -CORRECT
#     entry:      30664.5
#     sl:         30608.4
#     tp:         30776.7
#     fvg generated at: 14:05
#     tp at time: 15:00
#     sl at time:
#     result: W
# 2. 4 Julio BEARISH - CORECT
#     entry:      30994.3
#     sl:         31036.1
#     tp:         30910.7
#     fvg generated at: 14:45
#     tp at time: 15:25
#     sl at time:
#     result: W
# 3. 5 Julio BULLISH -CORRECT (NO LA EJECUCION)
#     entry:      30369.2
#     sl:         30316.6
#     tp:         30474.4
#     fvg generated at: 14:20
#     tp at time:
#     sl at time: 15:15
#     result: L
# 4. 6 Julio BULISH (NO HAY CONFIRMACION DE EJECUCION)
#     entry:      30049.2
#     sl:         29873.0
#     tp:         30401.6
#     fvg generated at: 14:45
#     tp at time: 15:40
#     sl at time:
#     result: W
# 5. 7 Julio BEARISH
#     entry:      30327.5
#     sl:         30404.9
#     tp:         30172.7
#     fvg generated at: 14:15
#     tp at time:
#     sl at time: 14:55
#     result: L
# 6. 10 Julio BEARISH
#     entry:      30221.9
#     sl:         30301.8
#     tp:         30062.4
#     fvg generated at: 14:40
#     tp at time:
#     sl at time: 14:50
#     result: L
# 7. 11 Julio BULISH NOT FILLED-CANCELED BC TP CROSS
#     entry:      30437.8
#     sl:         30360.1
#     tp:         30592.9
#     fvg generated at: 14:30
#     tp at time: - (15:10)
#     sl at time: -
#     result: W
# 8. 12 Julio BULLISH
#     entry: 30740.0
#     sl:         30589.4
#     tp:         31041.4
#     fvg generated at: 14:05
#     tp at time:
#     sl at time: 15:35
#     result: L
# 9. 3 Julio
#     entry:
#     sl:
#     tp:
#     fvg generated at:
#     tp at time:
#     sl at time:
#     result: W
# 10. 3 Julio
#     entry:
#     sl:
#     tp:
#     fvg generated at:
#     tp at time:
#     sl at time:
#     result: W
